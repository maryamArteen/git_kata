# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd

import numpy as np

# %%
def load_data():
    """Load the Titanic dataset into a Pandas DataFrame with only male passengers."""
    df = pd.read_csv("/workspaces/git_kata/data/titanic.csv")
    return df[df["Sex"] == "male"]

# %%
def clean_data(df):
    """
    Clean the given DataFrame by:
    - Dropping rows with missing values in selected important columns
    - Converting all string (categorical) columns to lowercase
    """
    df = df.dropna(subset=['pclass', 'sex', 'age'])  # customize columns

    for col in df.select_dtypes(include=['object']).columns:
        df[col] = df[col].str.lower()

    return df

# %%
cleaned_titanic = clean_data(titanic)


cleaned_titanic.head(10)
# Out:
# /tmp/ipykernel_43817/443336881.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].str.lower()
#    pclass  survived                                             name     sex  \
# 0       1         1                    allen, miss. elisabeth walton  female
# 1       1         1                   allison, master. hudson trevor    male
# 2       1         0                     allison, miss. helen loraine  female
# 3       1         0             allison, mr. hudson joshua creighton    male
# 4       1         0  allison, mrs. hudson j c (bessie waldo daniels)  female
# 5       1         1                              anderson, mr. harry    male
# ...

# %%
import matplotlib.pyplot as plt

# Plot passenger class distribution
cleaned_titanic['pclass'].value_counts().sort_index().plot(kind='bar')
plt.title('Passenger Class Distribution')
plt.xlabel('Passenger Class')
plt.ylabel('Number of Passengers')
plt.show()

# %%
print(cleaned_titanic.columns)
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
# Plot a histogram of the Age column
plt.hist(cleaned_titanic['age'], bins=30, edgecolor='black')
plt.title('Distribution of Passenger Age')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.show()
